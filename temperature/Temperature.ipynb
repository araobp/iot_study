# %% [markdown]
# # Temperature rise
#
# Measurement date: August 4, 2018
#
# Location: second floor of my house
#
# Heat the following materials under strong sunshine:
# - Black metal plate
# - White metal plate
# - Black sponge rubber

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.signal as sg

matplotlib.rcParams['figure.figsize'] = [16, 6]
FILE1 = 'temperature.csv'
FILE2 = 'temperature2.csv'

# %%
df = pd.read_csv(FILE1)
df.head()
# Out:
#    elapsed time  white metal  black metal  black sponge rubber
# 0             0         33.0         31.9                 33.4
# 1            30         34.3         33.3                 36.1
# 2            60         35.9         35.9                 37.6
# 3            90         37.5         39.8                 40.3
# 4           120         38.9         41.7                 41.4

# %%
# Initial temperature adjustment
df['black metal'] = df['black metal'].shift(-1)
df.head(100)
# Out:
#     elapsed time  white metal  black metal  black sponge rubber
# 0              0         33.0         33.3                 33.4
# 1             30         34.3         35.9                 36.1
# 2             60         35.9         39.8                 37.6
# 3             90         37.5         41.7                 40.3
# 4            120         38.9         43.9                 41.4
# 5            150         40.0         45.4                 43.3
# 6            180         41.3         46.5                 45.0
# 7            210         41.7         48.4                 46.0
# 8            240         42.3         49.5                 46.4
# 9            270         43.0         50.8                 46.8
# 10           300         43.4         52.1                 47.9
# 11           330         43.3         52.3                 48.8
# 12           360         44.1         53.1                 49.2
# 13           390         44.1         54.1                 49.0
# 14           420         44.5         54.4                 48.9
# 15           450         45.2         54.5                  NaN
# 16           480         45.7         54.9                  NaN
# 17           510         46.2         55.5                  NaN
# 18           540         45.9         56.2                  NaN
# 19           570         45.8         56.5                  NaN
# 20           600          NaN         56.4                  NaN
# 21           630          NaN          NaN                  NaN

# %%
ax = df[['white metal', 'black metal','black sponge rubber']].plot(x=df['elapsed time'], title='Temperature')
ax.set_xlabel('Elaplsed time in sec')
ax.set_ylabel('Temperature in degrees Celsius')
# Out:
# Text(0,0.5,'Temperature in degrees Celsius')

# %%
df2 = pd.read_csv(FILE2)
df2.head()
# Out:
#    elapsed time  white sponge rubber  black sponge rubber
# 0             0                 31.3                 33.7
# 1            30                 33.1                 34.3
# 2            60                 34.5                 35.3
# 3            90                 35.4                 37.0
# 4           120                 36.0                 38.6

# %%
# Initial temperature adjustment
df2['white sponge rubber'] = df2['white sponge rubber'].shift(-2)
df2['black sponge rubber'] = df2['black sponge rubber'].shift(-1)

df2.head(100)
# Out:
#     elapsed time  white sponge rubber  black sponge rubber
# 0              0                 34.5                 34.3
# 1             30                 35.4                 35.3
# 2             60                 36.0                 37.0
# 3             90                 36.4                 38.6
# 4            120                 37.0                 39.7
# 5            150                 37.7                 40.5
# 6            180                 38.5                 41.3
# 7            210                 38.5                 42.0
# 8            240                 38.6                 42.8
# 9            270                 38.9                 43.1
# 10           300                 39.3                 43.6
# 11           330                 39.2                 44.0
# 12           360                  NaN                 44.5
# 13           390                  NaN                 44.3
# 14           420                  NaN                 44.4
# 15           450                  NaN                  NaN

# %%
ax = df2[['black sponge rubber','white sponge rubber']].plot(x=df2['elapsed time'], title='Temperature')
ax.set_xlabel('Elaplsed time in sec')
ax.set_ylabel('Temperature in degrees Celsius')
# Out:
# Text(0,0.5,'Temperature in degrees Celsius')
