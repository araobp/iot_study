# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage

# %%
import skimage.filters as skif
import skimage.data as skid
# %matplotlib inline

# %%
def show(img):
    plt.imshow(img, cmap=plt.cm.gray)
    plt.axis('off')
    plt.show()

# %%
img = skimage.io.imread('doll.jpg')
show(img)
img = skimage.img_as_float(img)[...,0]
show(img)

# %%
show(skif.gaussian(img, 5.))

# %%
sobimg = skif.sobel(img)
show(sobimg<0.07)
